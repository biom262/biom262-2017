# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
directory = "/projects/ps-yeolab/biom262_2017/rmats/"
SE = pd.read_table(directory+"U2AF1-LV08-K562-SE.MATS.JunctionCountOnly.txt",
                  index_col=0)
SE.head()
# Out:
#                    GeneID geneSymbol    chr strand  exonStart_0base  \
# ID
# 10981   ENSG00000117748.5       RPA2   chr1      -         28224143
# 11710   ENSG00000173915.8      USMG5  chr10      -        105155502
# 12295   ENSG00000166902.4     MRPL16  chr11      -         59576205
# 12296   ENSG00000166902.4     MRPL16  chr11      -         59576205
# 12763  ENSG00000015479.13      MATR3   chr5      +        138651393
#
#          exonEnd  upstreamES  upstreamEE  downstreamES  downstreamEE  \
# ID
# 10981   28224218    28223515    28223632      28233438      28233552
# 11710  105155789   105152138   105152223     105156165     105156198
# 12295   59576345    59574708    59575322      59577327      59577495
# 12296   59576349    59574708    59575322      59577327      59577495
# 12763  138651427   138645731   138650425     138651764     138651837
#
#              ...          SJC_SAMPLE_1 IJC_SAMPLE_2 SJC_SAMPLE_2 IncFormLen  \
# ID           ...
# ...

# %%
SE.columns
# Out:
# Index([u'GeneID', u'geneSymbol', u'chr', u'strand', u'exonStart_0base',
#        u'exonEnd', u'upstreamES', u'upstreamEE', u'downstreamES',
#        u'downstreamEE', u'ID.1', u'IJC_SAMPLE_1', u'SJC_SAMPLE_1',
#        u'IJC_SAMPLE_2', u'SJC_SAMPLE_2', u'IncFormLen', u'SkipFormLen',
#        u'PValue', u'FDR', u'IncLevel1', u'IncLevel2', u'IncLevelDifference'],
#       dtype='object')

# %%
columns_to_looks_at = [u'GeneID', u'geneSymbol', u'chr', u'strand', u'exonStart_0base',
       u'exonEnd',u'IJC_SAMPLE_1', u'SJC_SAMPLE_1',
       u'IJC_SAMPLE_2', u'SJC_SAMPLE_2',u'PValue',
        u'FDR', u'IncLevel1', u'IncLevel2', u'IncLevelDifference']

# %%
print SE.shape
SE[columns_to_looks_at].head()
# Out:
# (42728, 22)
#                    GeneID geneSymbol    chr strand  exonStart_0base  \
# ID
# 10981   ENSG00000117748.5       RPA2   chr1      -         28224143
# 11710   ENSG00000173915.8      USMG5  chr10      -        105155502
# 12295   ENSG00000166902.4     MRPL16  chr11      -         59576205
# 12296   ENSG00000166902.4     MRPL16  chr11      -         59576205
# 12763  ENSG00000015479.13      MATR3   chr5      +        138651393
#
#          exonEnd IJC_SAMPLE_1 SJC_SAMPLE_1 IJC_SAMPLE_2 SJC_SAMPLE_2  PValue  \
# ID
# 10981   28224218      442,523        55,56      419,503          5,3       0
# 11710  105155789        46,27      696,683      161,178      615,619       0
# 12295   59576345      101,137        74,66         9,17      159,170       0
# 12296   59576349        63,80        74,66         6,13      159,170       0
# 12763  138651427        73,77      202,240      119,149        34,56       0
#
#        FDR    IncLevel1    IncLevel2  IncLevelDifference
# ID
# ...

# %%
sns.boxplot(SE['FDR'])

# %%
sns.boxplot(SE['IncLevelDifference'])

# %%
SE[columns_to_looks_at].head()
# Out:
#                    GeneID geneSymbol    chr strand  exonStart_0base  \
# ID
# 10981   ENSG00000117748.5       RPA2   chr1      -         28224143
# 11710   ENSG00000173915.8      USMG5  chr10      -        105155502
# 12295   ENSG00000166902.4     MRPL16  chr11      -         59576205
# 12296   ENSG00000166902.4     MRPL16  chr11      -         59576205
# 12763  ENSG00000015479.13      MATR3   chr5      +        138651393
#
#          exonEnd IJC_SAMPLE_1 SJC_SAMPLE_1 IJC_SAMPLE_2 SJC_SAMPLE_2  PValue  \
# ID
# 10981   28224218      442,523        55,56      419,503          5,3       0
# 11710  105155789        46,27      696,683      161,178      615,619       0
# 12295   59576345      101,137        74,66         9,17      159,170       0
# 12296   59576349        63,80        74,66         6,13      159,170       0
# 12763  138651427        73,77      202,240      119,149        34,56       0
#
#        FDR    IncLevel1    IncLevel2  IncLevelDifference
# ID
# ...

# %%
abs(SE['IncLevelDifference']) > 0.2
# Out:
# ID
# 10981    False
# 11710    False
# 12295     True
# 12296     True
# 12763     True
# 12773     True
# 14803     True
# 14805     True
# 1483      True
# 1495     False
# 15433    False
# 15927    False
# 164       True
# 165       True
# 16502     True
# 17351    False
# 17538     True
# 17545     True
# 1802      True
# 1932     False
# 20298     True
# 20313     True
# 21455     True
# 24581    False
# 24825     True
# 24826     True
# 25311    False
# 26301     True
# 27088     True
# 27089     True
#          ...
# 9948     False
# 9949     False
# 9950     False
# 9951     False
# 9952     False
# 9953     False
# 9954     False
# 9955     False
# 9956     False
# 9957     False
# 9958     False
# 9962      True
# 9963     False
# 9966     False
# 9968     False
# 9971     False
# 9973     False
# 9975     False
# 9977     False
# 9978     False
# 9979     False
# 998      False
# 9984     False
# 9985     False
# 9987     False
# 9988     False
# 9989     False
# ...

# %%
#FDR < 0.05, and abs(IncLevelDifference) > 0.2

SE_filtered = SE.loc[(SE["FDR"] < 0.05) & 
                    (abs(SE['IncLevelDifference']) > 0.2)]
print SE.shape
print SE_filtered.shape
SE_filtered.head()
# Out:
# (42728, 22)
# (849, 22)
#                    GeneID geneSymbol    chr strand  exonStart_0base  \
# ID
# 12295   ENSG00000166902.4     MRPL16  chr11      -         59576205
# 12296   ENSG00000166902.4     MRPL16  chr11      -         59576205
# 12763  ENSG00000015479.13      MATR3   chr5      +        138651393
# 12773  ENSG00000015479.13      MATR3   chr5      +        138651385
# 14803   ENSG00000132341.7        RAN  chr12      +        131357128
#
#          exonEnd  upstreamES  upstreamEE  downstreamES  downstreamEE  \
# ID
# 12295   59576345    59574708    59575322      59577327      59577495
# 12296   59576349    59574708    59575322      59577327      59577495
# 12763  138651427   138645731   138650425     138651764     138651837
# 12773  138651427   138650363   138650425     138651764     138651877
# 14803  131357174   131356626   131356671     131357380     131357465
#
#              ...          SJC_SAMPLE_1 IJC_SAMPLE_2 SJC_SAMPLE_2 IncFormLen  \
# ID           ...
# ...

# %%
sns.boxplot(SE_filtered['IncLevelDifference'])

# %%
plt.hist(SE_filtered['IncLevelDifference'], bins=100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-35ddfe38c052> in <module>()
# ----> 1 plt.hist(SE_filtered['IncLevelDifference'], bins=100)
#
# /home/ecwheele/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2894                       histtype=histtype, align=align, orientation=orientation,
#    2895                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2896                       stacked=stacked, **kwargs)
#    2897         draw_if_interactive()
#    2898     finally:
#
# ...

# %%
SE_filtered.sort(columns = 'IncLevelDifference', ascending=False)[columns_to_looks_at].head(50)
# Out:
# /home/ecwheele/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                    GeneID  geneSymbol    chr strand  exonStart_0base  \
# ID
# 25444  ENSG00000151276.19       MAGI1   chr3      -         65433696
# 57222   ENSG00000166747.8       AP1G1  chr16      -         71841703
# 19904  ENSG00000182149.16        IST1  chr16      +         71957141
# 41790  ENSG00000092140.10        G2E3  chr14      +         31059737
# 22319  ENSG00000105953.10        OGDH   chr7      +         44695916
# 41787  ENSG00000092140.10        G2E3  chr14      +         31059737
# 66467  ENSG00000129187.10        DCTD   chr4      -        183837033
# 22189   ENSG00000120725.8        SIL1   chr5      -        138463632
# 38271   ENSG00000171159.4     C9orf16   chr9      +        130924282
# 13401  ENSG00000170633.12       RNF34  chr12      +        121840544
# ...

# %%
A3SS = pd.read_table(directory+"U2AF1-LV08-K562-A3SS.MATS.JunctionCountOnly.txt",
                  index_col=0)
print A3SS.shape
A3SS.head()
# Out:
# (12586, 22)
#                    GeneID geneSymbol    chr strand  longExonStart_0base  \
# ID
# 10311   ENSG00000255717.2      SNHG1  chr11      -             62621272
# 10313   ENSG00000255717.2      SNHG1  chr11      -             62621272
# 11471  ENSG00000185686.13      PRAME  chr22      -             22899231
# 11474  ENSG00000185686.13      PRAME  chr22      -             22899231
# 11808   ENSG00000234741.3       GAS5   chr1      -            173833394
#
#        longExonEnd    shortES    shortEE  flankingES  flankingEE  \
# ID
# 10311     62621536   62621272   62621305    62621990    62622023
# 10313     62621461   62621272   62621305    62621990    62622023
# 11471     22899350   22899231   22899329    22899964    22900000
# 11474     22899397   22899231   22899329    22899964    22900000
# 11808    173833644  173833394  173833442   173833812   173833835
#
#              ...          SJC_SAMPLE_1 IJC_SAMPLE_2 SJC_SAMPLE_2 IncFormLen  \
# ID           ...
# ...

# %%
A3SS_filtered = A3SS.loc[(A3SS['FDR'] < 0.05) &
                        (abs(A3SS['IncLevelDifference']) > 0.2)]
print A3SS.shape
print A3SS_filtered.shape
A3SS_filtered.head()
# Out:
# (12586, 22)
# (73, 22)
#                    GeneID geneSymbol    chr strand  longExonStart_0base  \
# ID
# 10311   ENSG00000255717.2      SNHG1  chr11      -             62621272
# 10313   ENSG00000255717.2      SNHG1  chr11      -             62621272
# 11474  ENSG00000185686.13      PRAME  chr22      -             22899231
# 14778   ENSG00000185043.6       CIB1  chr15      -             90775450
# 587     ENSG00000205352.6      PRR13  chr12      +             53837174
#
#        longExonEnd   shortES   shortEE  flankingES  flankingEE  \
# ID
# 10311     62621536  62621272  62621305    62621990    62622023
# 10313     62621461  62621272  62621305    62621990    62622023
# 11474     22899397  22899231  22899329    22899964    22900000
# 14778     90775679  90775450  90775559    90776900    90776935
# 587       53837557  53837462  53837557    53836478    53836517
#
#              ...          SJC_SAMPLE_1 IJC_SAMPLE_2 SJC_SAMPLE_2 IncFormLen  \
# ID           ...
# ...

# %%
plt.hist(A3SS_filtered['IncLevelDifference'],bins=100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-cde83482b830> in <module>()
# ----> 1 plt.hist(A3SS['IncLevelDifference'],bins=100)
#
# /home/ecwheele/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2894                       histtype=histtype, align=align, orientation=orientation,
#    2895                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2896                       stacked=stacked, **kwargs)
#    2897         draw_if_interactive()
#    2898     finally:
#
# ...

# %%
A3SS_filtered.sort(columns='IncLevelDifference', ascending=False).head()
# Out:
# /home/ecwheele/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                    GeneID geneSymbol    chr strand  longExonStart_0base  \
# ID
# 150     ENSG00000085231.9       TAF9   chr5      -             68662329
# 3385   ENSG00000185722.12     ANKFY1  chr17      -              4071129
# 6714    ENSG00000139641.8      ESYT1  chr12      +             56527863
# 15827  ENSG00000135473.10       PAN2  chr12      -             56720096
# 14778   ENSG00000185043.6       CIB1  chr15      -             90775450
#
#        longExonEnd   shortES   shortEE  flankingES  flankingEE  \
# ID
# 150       68662552  68662329  68662422    68664453    68664510
# 3385       4071374   4071129   4071205     4072491     4072582
# 6714      56527965  56527893  56527965    56527564    56527657
# 15827     56720217  56720096  56720193    56720400    56720743
# ...
